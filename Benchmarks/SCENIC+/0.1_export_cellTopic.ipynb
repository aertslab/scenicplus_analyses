# %%
import pandas as pd
cistopic_obj = pd.read_pickle('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/analysis/DPCL/pycisTopic/DPCL_cisTopicObject.pkl')

# %%
model = cistopic_obj.selected_model
cell_topic = model.cell_topic
cell_topic
# Out:
#          K562_33___DPLC  K562_69___DPLC  K562_206___DPLC  Panc1_80___DPLC  \
# Topic1         0.000240        0.000132         0.009228         0.000341
# Topic2         0.003549        0.000132         0.000883         0.026557
# Topic3         0.001734        0.003736         0.000348         0.006318
# Topic4         0.001094        0.000768         0.001204         0.000865
# Topic5         0.003869        0.001828         0.000134         0.107304
# Topic6         0.002161        0.001192         0.036616         0.004535
# Topic7         0.000774        0.001722         0.000883         0.003801
# Topic8         0.008352        0.002888         0.001097         0.001389
# Topic9         0.000240        0.000450         0.002059         0.002648
# Topic10        0.000560        0.004266         0.003557         0.006947
# Topic11        0.091712        0.025673         0.000990         0.000446
# Topic12        0.002802        0.100599         0.003236         0.004326
# ...

# %%
import pandas as pd
cell_topic.to_csv('/data/leuven/312/vsc31245/jupyterhub_notebooks/SCENICplus/FigR_encode/analysis/cell_topic.txt', sep='\t')

# %%
umap = cistopic_obj.projections['cell']['UMAP']
umap.to_csv('/data/leuven/312/vsc31245/jupyterhub_notebooks/SCENICplus/FigR_encode/analysis/cell_umap.txt', sep='\t')

# %%
cistopic_obj.cell_data.to_csv('/data/leuven/312/vsc31245/jupyterhub_notebooks/SCENICplus/FigR_encode/analysis/cell_data.txt', sep='\t')
