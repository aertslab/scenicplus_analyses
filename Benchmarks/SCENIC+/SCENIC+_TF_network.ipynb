# %%
outDir = '/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/analysis/DPCL/scenicplus_final_autoreg/grnboost/'
import dill
infile = open(outDir+'scplus_obj.pkl', 'rb')
scplus_obj = dill.load(infile)
infile.close()

# %%
import os 
os.chdir('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/scenicplus/src/scenicplus')
from scenicplus.networks import *
subset_genes = ['STAT5A', 'GATA1', 'GATA2', 'SFPQ', 'HOXB9', 'HOXB4', 'ARID3A', 'STAT1', 'BHLHE40']
nx_tables = create_nx_tables(scplus_obj,
                    eRegulon_metadata_key = 'eRegulon_metadata',
                    subset_eRegulons = subset_genes,
                    subset_regions = None,
                    subset_genes = subset_genes,
                    add_differential_gene_expression = False,
                    add_differential_region_accessibility = False)

# %%
nx_tables['Edge']['TF2G']
# Out:
#            TF     Gene Gene_signature_name Region_signature_name  \
# 146    ARID3A   ARID3A   ARID3A_+_+_(817g)    ARID3A_+_+_(1386r)
# 177   BHLHE40  BHLHE40  BHLHE40_+_+_(300g)    BHLHE40_+_+_(528r)
# 306     GATA1    HOXB4    GATA1_+_+_(946g)     GATA1_+_+_(2080r)
# 820     GATA1    GATA1    GATA1_+_+_(946g)     GATA1_+_+_(2080r)
# 1682    GATA1    HOXB9    GATA1_+_+_(946g)     GATA1_+_+_(2080r)
# 1980    GATA1    GATA2    GATA1_+_+_(946g)     GATA1_+_+_(2080r)
# 2177    GATA1   STAT5A    GATA1_+_+_(946g)     GATA1_+_+_(2080r)
# 237     GATA2    HOXB4    GATA2_+_+_(974g)     GATA2_+_+_(2134r)
# 273     GATA2    HOXB9    GATA2_+_+_(974g)     GATA2_+_+_(2134r)
# 733     GATA2    GATA1    GATA2_+_+_(974g)     GATA2_+_+_(2134r)
# 1692    GATA2    GATA2    GATA2_+_+_(974g)     GATA2_+_+_(2134r)
# 1960    GATA2   STAT5A    GATA2_+_+_(974g)     GATA2_+_+_(2134r)
# 113     HOXB9    HOXB4    HOXB9_+_+_(333g)      HOXB9_+_+_(367r)
# 144     HOXB9    HOXB9    HOXB9_+_+_(333g)      HOXB9_+_+_(367r)
# 441     HOXB9    GATA2    HOXB9_+_+_(333g)      HOXB9_+_+_(367r)
# 69       SFPQ    GATA1      SFPQ_+_+_(81g)        SFPQ_+_+_(58r)
# 1902    STAT1    STAT1   STAT1_+_+_(1303g)     STAT1_+_+_(4976r)
# 86     STAT5A  BHLHE40   STAT5A_+_+_(684g)     STAT5A_+_+_(993r)
# 401    STAT5A   ARID3A   STAT5A_+_+_(684g)     STAT5A_+_+_(993r)
# 468    STAT5A   STAT5A   STAT5A_+_+_(684g)     STAT5A_+_+_(993r)
# 483    STAT5A    HOXB9   STAT5A_+_+_(684g)     STAT5A_+_+_(993r)
# 819    STAT5A    HOXB4   STAT5A_+_+_(684g)     STAT5A_+_+_(993r)
# 149    ARID3A   ARID3A   ARID3A_+_-_(893g)    ARID3A_+_-_(1483r)
# 105     HOXB9    HOXB9    HOXB9_+_-_(193g)      HOXB9_+_-_(181r)
# 141     HOXB9    GATA2    HOXB9_+_-_(193g)      HOXB9_+_-_(181r)
# 1395    STAT1    STAT1    STAT1_+_-_(777g)     STAT1_+_-_(1446r)
#
#       TF2G_importance  TF2G_importance_x_abs_rho  TF2G_importance_x_rho  \
# 146         48.831442                  48.831442              48.831442
# 177         35.782367                  35.782367              35.782367
# 306          7.400148                   3.360704               3.360704
# 820         49.576187                  49.576187              49.576187
# 1682        31.310058                  25.243336              25.243336
# 1980        24.469068                  17.535461              17.535461
# 2177        36.963832                  31.584170              31.584170
# 237          5.705405                   2.596746               2.596746
# 273          2.803103                   2.123236               2.123236
# 733          2.392236                   1.714367               1.714367
# 1692        18.971215                  18.971215              18.971215
# 1960         3.448585                   2.341121               2.341121
# 113         26.466550                  14.850687              14.850687
# 144         40.914978                  40.914978              40.914978
# 441         10.102307                   7.652084               7.652084
# 69           1.556422                   0.856728               0.856728
# 1902        57.129261                  57.129261              57.129261
# 86          28.788509                  12.959281              12.959281
# 401          6.510774                   1.261337               1.261337
# 468         47.936564                  47.936564              47.936564
# 483         18.977867                  15.123621              15.123621
# 819          5.588260                   2.734687               2.734687
# 149         48.831442                  48.831442              48.831442
# 105         40.914978                  40.914978              40.914978
# 141         10.102307                   7.652084               7.652084
# 1395        57.129261                  57.129261              57.129261
#
#       TF2G_regulation  TF2G_rho is_extended
# 146                 1  1.000000       False
# 177                 1  1.000000       False
# 306                 1  0.454140       False
# 820                 1  1.000000       False
# 1682                1  0.806237       False
# 1980                1  0.716638       False
# 2177                1  0.854461       False
# 237                 1  0.455138       False
# 273                 1  0.757459       False
# 733                 1  0.716638       False
# 1692                1  1.000000       False
# 1960                1  0.678864       False
# 113                 1  0.561112       False
# 144                 1  1.000000       False
# 441                 1  0.757459       False
# 69                  1  0.550447       False
# 1902                1  1.000000       False
# 86                  1  0.450155       False
# 401                 1  0.193731       False
# 468                 1  1.000000       False
# 483                 1  0.796908       False
# 819                 1  0.489363       False
# 149                 1  1.000000       False
# 105                 1  1.000000       False
# 141                 1  0.757459       False
# 1395                1  1.000000       False

# %%
y=nx_tables['Edge']['TF2G'][['TF', 'Gene']].drop_duplicates()

# %%
y.to_csv('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/analysis/DPCL/scenicplus_final_autoreg/grnboost/K562_tf_network_simple.tsv', sep='\t', index=False)

# %%
import os 
os.chdir('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/scenicplus/src/scenicplus')
from scenicplus.networks import *
subset_genes = ['STAT5A', 'GATA1', 'GATA2', 'SFPQ', 'HOXB9', 'HOXB4', 'ARID3A', 'STAT1', 'BHLHE40']
nx_tables = create_nx_tables(scplus_obj,
                    eRegulon_metadata_key = 'eRegulon_metadata',
                    subset_regions = None,
                    subset_genes = subset_genes,
                    add_differential_gene_expression = False,
                    add_differential_region_accessibility = False)

# %%
nx_tables.keys()
# Out:
# dict_keys(['Edge', 'Node'])

# %%
nx_tables['Edge']['TF2G'][['TF', 'Gene']].drop_duplicates()
# Out:
#           TF     Gene
# 146   ARID3A   ARID3A
# 47      ATF5   ARID3A
# 220     ATF5   STAT5A
# 381     ATF5  BHLHE40
# 177  BHLHE40  BHLHE40
# ..       ...      ...
# 355     LMO2   STAT5A
# 522     LMO2    HOXB9
# 25     NPAS2    HOXB4
# 51    ZNF516  BHLHE40
# 792    FOXF1    GATA1
#
# [171 rows x 2 columns]

# %%
import os 
os.chdir('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/scenicplus/src/scenicplus')
from scenicplus.networks import *
subset_genes = list(set(list(nx_tables['Edge']['TF2G'][['TF', 'Gene']].drop_duplicates()['TF'])))
nx_tables = create_nx_tables(scplus_obj,
                    eRegulon_metadata_key = 'eRegulon_metadata',
                    subset_regions = None,
                    subset_genes = subset_genes,
                    add_differential_gene_expression = False,
                    add_differential_region_accessibility = False)

# %%
list(subset_genes)
# Out:
# ['LMO2',
#  'MYBL2',
#  'ZNF516',
#  'NR5A1',
#  'ASCL1',
#  'BNC2',
#  'GATA2',
#  'HNF4A',
#  'TBX2',
#  'HOXB9',
#  'IRF4',
#  'POU2AF1',
#  'BHLHE40',
#  'IKZF2',
#  'NFKB1',
#  'SOX9',
#  'NPAS2',
#  'IRF8',
#  'XBP1',
#  'RUNX3',
#  'FOXO1',
#  'FOXA1',
#  'ZXDB',
#  'GATA5',
#  'HLF',
#  'HIC1',
#  'HOXB8',
#  'IRF7',
#  'HOXB13',
#  'SMAD3',
#  'WT1',
#  'SFPQ',
#  'FOXL2',
#  'EGR1',
#  'CTCFL',
#  'ATF5',
#  'PAX2',
#  'FOXP1',
#  'PROX1',
#  'NFE2',
#  'MYB',
#  'NR6A1',
#  'RXRA',
#  'KLF1',
#  'MEF2C',
#  'TBX1',
#  'PPARG',
#  'GATA1',
#  'ZIC2',
#  'SOX4',
#  'FOXL1',
#  'ELF3',
#  'ARID3A',
#  'ETS2',
#  'LEF1',
#  'SPI1',
#  'FOSL1',
#  'IKZF3',
#  'SPDEF',
#  'MYC',
#  'FOXF1',
#  'SPIB',
#  'STAT5A',
#  'GFI1B',
#  'SP5',
#  'FOXP4',
#  'TAL1',
#  'BHLHE41',
#  'KLF5',
#  'KLF13',
#  'TEAD1',
#  'EBF1',
#  'NR1H4',
#  'STAT5B',
#  'ETV6',
#  'FOSL2',
#  'STAT2',
#  'IKZF1',
#  'STAT3',
#  'STAT1',
#  'ETV4',
#  'JUN',
#  'TCF7L2',
#  'EPAS1',
#  'LIN28B',
#  'FOXQ1']

# %%
x = nx_tables['Edge']['TF2G'][['TF', 'Gene']].drop_duplicates()

# %%
genes = ['STAT5A', 'GATA1', 'GATA2', 'SFPQ', 'HOXB9', 'HOXB4', 'ARID3A', 'STAT1', 'BHLHE40']
x1 = x[x['Gene'].isin(genes)]
x2 = x[x['TF'].isin(genes)]

# %%
y=pd.concat([x1, x2])

# %%
sel1=list(set(y[y['Gene'].isin(genes)]['TF']))
sel2=list(set(y[y['TF'].isin(genes)]['Gene']))
sel = [x for x in sel1 if x in sel2]
sel
# Out:
# ['LMO2',
#  'ZNF516',
#  'NR5A1',
#  'ASCL1',
#  'GATA2',
#  'HNF4A',
#  'TBX2',
#  'HOXB9',
#  'IRF4',
#  'POU2AF1',
#  'BHLHE40',
#  'IKZF2',
#  'NFKB1',
#  'SOX9',
#  'IRF8',
#  'RUNX3',
#  'HLF',
#  'HIC1',
#  'HOXB8',
#  'IRF7',
#  'SMAD3',
#  'WT1',
#  'FOXL2',
#  'EGR1',
#  'CTCFL',
#  'ATF5',
#  'FOXP1',
#  'NFE2',
#  'MYB',
#  'NR6A1',
#  'RXRA',
#  'KLF1',
#  'MEF2C',
#  'TBX1',
#  'GATA1',
#  'ZIC2',
#  'SOX4',
#  'FOXL1',
#  'ELF3',
#  'ARID3A',
#  'LEF1',
#  'SPI1',
#  'IKZF3',
#  'MYC',
#  'SPIB',
#  'STAT5A',
#  'GFI1B',
#  'SP5',
#  'TAL1',
#  'KLF13',
#  'TEAD1',
#  'EBF1',
#  'NR1H4',
#  'STAT5B',
#  'ETV6',
#  'STAT2',
#  'IKZF1',
#  'STAT1',
#  'ETV4',
#  'JUN',
#  'LIN28B']

# %%
y.to_csv('/staging/leuven/stg_00002/lcb/cbravo/Multiomics_pipeline/analysis/DPCL/scenicplus_final_autoreg/grnboost/K562_tf_network.tsv', sep='\t', index=FALSE)

# %%
G_c, pos_c, edge_tables_c, node_tables_c = create_nx_graph(nx_tables, 
                   use_edge_tables = ['TF2G'],
                   color_edge_by = {'TF2R': {'variable' : 'TF', 'category_color' : {'SOX10': 'Orange', 'OLIG2': 'Purple', 'TCF12': 'Red'}},
                                    'R2G': {'variable' : 'R2G_rho', 'continuous_color' : 'viridis', 'v_min': -1, 'v_max': 1}},
                   transparency_edge_by =  {'R2G': {'variable' : 'R2G_importance', 'min_alpha': 0.1, 'v_min': 0}},
                   width_edge_by = {'R2G': {'variable' : 'R2G_importance', 'max_size' :  1.5, 'min_size' : 1}},
                   color_node_by = {'TF': {'variable': 'TF', 'category_color' : {'SOX10': 'Orange', 'OLIG2': 'Purple',  'TCF12': 'Red'}},
                                    'Gene': {'variable': 'ACC_Seurat_cell_type_Log2FC_MOL', 'continuous_color' : 'bwr'},
                                    'Region': {'variable': 'ACC_Seurat_cell_type_Log2FC_MOL', 'continuous_color' : 'viridis'}},
                   transparency_node_by =  {'Region': {'variable' : 'ACC_Seurat_cell_type_Log2FC_MOL', 'min_alpha': 0.1},
                                    'Gene': {'variable' : 'ACC_Seurat_cell_type_Log2FC_MOL', 'min_alpha': 0.1},
                                    'TF': {'variable': 'fixed_alpha', 'fixed_alpha': 1}},
                   size_node_by = {'TF': {'variable': 'fixed_size', 'fixed_size': 30},
                                    'Gene': {'variable': 'fixed_size', 'fixed_size': 15},
                                    'Region': {'variable': 'fixed_size', 'fixed_size': 10}},
                   shape_node_by = {'TF': {'variable': 'fixed_shape', 'fixed_shape': 'ellipse'},
                                    'Gene': {'variable': 'fixed_shape', 'fixed_shape': 'ellipse'},
                                    'Region': {'variable': 'fixed_shape', 'fixed_shape': 'diamond'}},
                   label_size_by = {'TF': {'variable': 'fixed_label_size', 'fixed_label_size': 20.0},
                                    'Gene': {'variable': 'fixed_label_size', 'fixed_label_size': 10.0},
                                    'Region': {'variable': 'fixed_label_size', 'fixed_label_size': 0.0}},
                   layout='concentrical_layout',
                   scale_position_by=250)
